# %%
import pandas as pd

pd.options.display.max_rows # this is shows how many rows will be displayed by default.
# Out:
# 60

# %%
# Setting up alerts
#%pip install jupyternotify
# %load_ext jupyternotify

# %%
# %%notify
#
# import time
# import random
# r = random.randint(3,6)
# time.sleep(r)
# print("Cell finished executed")
# Out:
# Cell finished executed
